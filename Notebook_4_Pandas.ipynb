# %% [markdown]
# <a href="https://colab.research.google.com/github/Abeer-Rahman/Workshop-MolSSI-Python-Data-and-Scripting/blob/main/Notebook_4_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
periodic=pd.read_csv("PubChemsElement_all.csv")

# %%
periodic
# Out:
#      AtomicNumber Symbol         Name  AtomicMass CPKHexColor  \
# 0               1      H     Hydrogen    1.008000      FFFFFF
# 1               2     He       Helium    4.002600      D9FFFF
# 2               3     Li      Lithium    7.000000      CC80FF
# 3               4     Be    Beryllium    9.012183      C2FF00
# 4               5      B        Boron   10.810000      FFB5B5
# ..            ...    ...          ...         ...         ...
# 113           114     Fl    Flerovium  290.192000         NaN
# 114           115     Mc    Moscovium  290.196000         NaN
# 115           116     Lv  Livermorium  293.205000         NaN
# 116           117     Ts   Tennessine  294.211000         NaN
# 117           118     Og    Oganesson  295.216000         NaN
#
#                  ElectronConfiguration  Electronegativity  AtomicRadius  \
# 0                                  1s1               2.20         120.0
# 1                                  1s2                NaN         140.0
# ...

# %%
periodic.head()
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# ...

# %%
periodic.tail()
# Out:
#      AtomicNumber Symbol         Name  AtomicMass CPKHexColor  \
# 113           114     Fl    Flerovium     290.192         NaN
# 114           115     Mc    Moscovium     290.196         NaN
# 115           116     Lv  Livermorium     293.205         NaN
# 116           117     Ts   Tennessine     294.211         NaN
# 117           118     Og    Oganesson     295.216         NaN
#
#                  ElectronConfiguration  Electronegativity  AtomicRadius  \
# 113  [Rn]7s2 7p2 5f14 6d10 (predicted)                NaN           NaN
# 114  [Rn]7s2 7p3 5f14 6d10 (predicted)                NaN           NaN
# 115  [Rn]7s2 7p4 5f14 6d10 (predicted)                NaN           NaN
# 116  [Rn]7s2 7p5 5f14 6d10 (predicted)                NaN           NaN
# 117  [Rn]7s2 7p6 5f14 6d10 (predicted)                NaN           NaN
#
#      IonizationEnergy  ElectronAffinity        OxidationStates  \
# 113               NaN               NaN           6, 4,2, 1, 0
# ...

# %%
#Get statistisc
periodic.describe()
# Out:
#        AtomicNumber  AtomicMass  Electronegativity  AtomicRadius  \
# count    118.000000  118.000000          95.000000     99.000000
# mean      59.500000  146.539858           1.732316    209.464646
# std       34.207699   89.768306           0.635187     38.569130
# min        1.000000    1.008000           0.700000    120.000000
# 25%       30.250000   66.480750           1.290000    187.000000
# 50%       59.500000  142.573830           1.620000    209.000000
# 75%       88.750000  226.777165           2.170000    232.000000
# max      118.000000  295.216000           3.980000    348.000000
#
#        IonizationEnergy  ElectronAffinity  MeltingPoint  BoilingPoint  \
# count        102.000000         57.000000    103.000000     93.000000
# mean           7.997255          1.072140   1273.740553   2536.212473
# std            3.339066          0.879163    888.853859   1588.410919
# min            3.894000          0.079000      0.950000      4.220000
# ...

# %% [markdown]
# ## Accessing Data Type

# %%
#get information using number
periodic.iloc[0,1]
# Out:
# 'H'

# %%
periodic.iloc[:5]
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# ...

# %%
periodic.iloc[5,:]
# Out:
# AtomicNumber                       6
# Symbol                             C
# Name                          Carbon
# AtomicMass                    12.011
# CPKHexColor                   909090
# ElectronConfiguration    [He]2s2 2p2
# Electronegativity               2.55
# AtomicRadius                   170.0
# IonizationEnergy               11.26
# ElectronAffinity               1.263
# OxidationStates           +4, +2, -4
# StandardState                  Solid
# MeltingPoint                  3823.0
# BoilingPoint                  4098.0
# Density                        2.267
# GroupBlock                  Nonmetal
# YearDiscovered               Ancient
# Name: 5, dtype: object

# %%
periodic.iloc[30:,2]
# Out:
# 30         Gallium
# 31       Germanium
# 32         Arsenic
# 33        Selenium
# 34         Bromine
#           ...
# 113      Flerovium
# 114      Moscovium
# 115    Livermorium
# 116     Tennessine
# 117      Oganesson
# Name: Name, Length: 88, dtype: object

# %%
#get column using a column name
#periodic["Column_Name"]
periodic["IonizationEnergy"]
# Out:
# 0      13.598
# 1      24.587
# 2       5.392
# 3       9.323
# 4       8.298
#         ...
# 113       NaN
# 114       NaN
# 115       NaN
# 116       NaN
# 117       NaN
# Name: IonizationEnergy, Length: 118, dtype: float64

# %%
periodic[["Symbol","IonizationEnergy"]]
# Out:
#     Symbol  IonizationEnergy
# 0        H            13.598
# 1       He            24.587
# 2       Li             5.392
# 3       Be             9.323
# 4        B             8.298
# ..     ...               ...
# 113     Fl               NaN
# 114     Mc               NaN
# 115     Lv               NaN
# 116     Ts               NaN
# 117     Og               NaN
#
# [118 rows x 2 columns]

# %%
periodic["MeltingPoint"]-273.15
# Out:
# 0      -259.34
# 1      -272.20
# 2       180.50
# 3      1286.85
# 4      2074.85
#         ...
# 113        NaN
# 114        NaN
# 115        NaN
# 116        NaN
# 117        NaN
# Name: MeltingPoint, Length: 118, dtype: float64

# %%
periodic["MeltingPointC"]=periodic["MeltingPoint"]-273.15

# %%
periodic.head()
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# ...

# %%
greater100=periodic.query("MeltingPointC>100")
# Out:
#      AtomicNumber Symbol         Name  AtomicMass CPKHexColor  \
# 2               3     Li      Lithium    7.000000      CC80FF
# 3               4     Be    Beryllium    9.012183      C2FF00
# 4               5      B        Boron   10.810000      FFB5B5
# 5               6      C       Carbon   12.011000      909090
# 11             12     Mg    Magnesium   24.305000      8AFF00
# ..            ...    ...          ...         ...         ...
# 98             99     Es  Einsteinium  252.083000      B31FD4
# 99            100     Fm      Fermium  257.095110      B31FBA
# 100           101     Md  Mendelevium  258.098430      B30DA6
# 101           102     No     Nobelium  259.101000      BD0D87
# 102           103     Lr   Lawrencium  266.120000      C70066
#
#     ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 2                 [He]2s1               0.98         182.0             5.392
# ...
