# %% [markdown]
# <a href="https://colab.research.google.com/github/Abeer-Rahman/Workshop-MolSSI-Python-Data-and-Scripting/blob/main/Notebook%201%3A%20File_Parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # File Parsing

# %%
pwd
# Out:
# '/home/nanohub/rahman.abeer1994/molssi_workshop'

# %%
import os

# %%
ethanol_file=os.path.join('data','outfiles','ethanol.out')
print(ethanol_file)
# Out:
# data/outfiles/ethanol.out

# %%
outfile=open(ethanol_file,'r')
data=outfile.readlines()
outfile.close()

# %%
print(data[10])
# Out:
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,

# %%
print(len(data))
# Out:
# 270

# %%
for line in data:
    if 'Final Energy' in line:
        energy_line=line
print(energy_line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
words=energy_line.split()
print(words)
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy_line.split(':')
# Out:
# ['  @DF-RHF Final Energy', '  -154.09130176573018\n']

# %%
energy=words[3]
print(energy)
# Out:
# -154.09130176573018

# %%
float(energy)+50
# Out:
# -104.09130176573018

# %% [markdown]
# ## For accessing multiple files

# %%
import glob
file_location=os.path.join('data','outfiles','*.out')
filenames=glob.glob(file_location)
print(filenames)
# Out:
# ['data/outfiles/butanol.out', 'data/outfiles/decanol.out', 'data/outfiles/ethanol.out', 'data/outfiles/heptanol.out', 'data/outfiles/hexanol.out', 'data/outfiles/methanol.out', 'data/outfiles/nonanol.out', 'data/outfiles/octanol.out', 'data/outfiles/pentanol.out', 'data/outfiles/propanol.out']

# %%
datafile=open('energies.txt','w+')
for file in filenames:
    outfile=open(file,'r')
    data=outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line=line
            words=energy_line.split()
            energy=float(words[3])
            datafile.write(F'{file}: {energy}\n')
datafile.close()

# %% [markdown]
# # Excercise:
# ## calculating the interaction energy for an ethene-ethyne complex

# %%
import os
filename=os.path.join('data','sapt.out')
print(filename)
# Out:
# data/sapt.out

# %%
outfile=open(filename,'r')
data=outfile.readlines()
outfile.close
search_list=['Electrostatics      ','Exchange      ','Induction    ','Dispersion    ']
sorted_list=[]
for line in data:
    for i in search_list:
        if i in line:
             i=line
             sorted_list.append(i)
total_energy=0
for k in range(len(sorted_list)):
       words=sorted_list[k].split()
       print(words[0],":", words[3],'Kcal/mol')
       total_energy=total_energy+ float(words[3])
print(F'Total Energy: {total_energy} Kcal/mol')
# Out:
# Electrostatics : -2.25850118 Kcal/mol
# Exchange : 2.27730198 Kcal/mol
# Induction : -0.52169330 Kcal/mol
# Dispersion : -0.94466770 Kcal/mol
# Total Energy: -1.4475602000000003 Kcal/mol

# %%
#Solution provided by the instructor
important_lines = []
energies = []

with open('data/sapt.out','r') as saptout:
    for line in saptout:
        if 'Electrostatics    ' in line:
            electro_line = line
            important_lines.append(electro_line)
        if 'Exchange       ' in line:
            exchange_line = line
            important_lines.append(exchange_line)
        if 'Induction      ' in line:
            induction_line = line
            important_lines.append(induction_line)
        if 'Dispersion     ' in line:
            dispersion_line = line
            important_lines.append(dispersion_line)

# print(important_lines)

for line in important_lines:
    words = line.split()
    # print(words)
    energy_type = words[0]
    energy_kcal = float(words[3])
    energies.append(energy_kcal)
    print('{} : {} kcal/mol'.format(energy_type, energy_kcal))

total_energy = sum(energies)
print('Total Energy : {} kcal/mol'.format(total_energy))
# Out:
# Electrostatics : -2.25850118 kcal/mol
# Exchange : 2.27730198 kcal/mol
# Induction : -0.5216933 kcal/mol
# Dispersion : -0.9446677 kcal/mol
# Total Energy : -1.4475602000000003 kcal/mol

# %% [markdown]
# # Homework Problem
# 03_Prod.mdout(SINGLE FILE PARSING)

# %%
import os
file_location=os.path.join('data','03_Prod.mdout')
#print(file_location)
outfile=open(file_location,'r')
data=outfile.readlines()
outfile.close()
total_energy=[]
for line in data:
    if "Etot   =    " in line:
        Etot=line
        words=Etot.split()
        #print(words)
        etot_value=float(words[2])
        #print(etot_value)
        total_energy.append(etot_value)
        print('Total Energies:',total_energy)
# Out:
# Total Energies: [-4585.1049]
# Total Energies: [-4585.1049, -4573.5326]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995, -4550.9376]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995, -4550.9376, -4543.8652]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995, -4550.9376, -4543.8652, -4570.4109]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995, -4550.9376, -4543.8652, -4570.4109, -4550.4225]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995, -4550.9376, -4543.8652, -4570.4109, -4550.4225, -4585.2078]
# Total Energies: [-4585.1049, -4573.5326, -4548.1223, -4525.341, -4542.8995, -4550.9376, -4543.8652, -4570.4109, -4550.4225, -4585.2078, -4577.3788]
# ...

# %% [markdown]
# Multiple mdout files

# %%
file_location=os.path.join('data','mdout','*.mdout')
import glob
file_names=glob.glob(file_location)
print(file_names)
# Out:
# ['data/mdout/polyAT_gb_md1_12Acut.mdout', 'data/mdout/polyAT_vac_md1_12Acut.mdout', 'data/mdout/polyAT_vac_md1_nocut.mdout', 'data/mdout/polyAT_wat_md2.mdout']

# %%
for file in file_names:
    mdfile=open(file,'r')
    data=mdfile.readlines()
    mdfile.close()
    total_energy=[]
    for line in data:
        if "Etot   =    " in line:
              Etot=line
              words=Etot.split()
              #print(words)
              etot_value=float(words[2])
              #print(etot_value)
              total_energy.append(etot_value)

    print(F'{file}: {total_energy}')
# Out:
# data/mdout/polyAT_gb_md1_12Acut.mdout: [-2750.8246, -2669.5259, -2614.9904, -2563.7055, -2525.8346, -2496.8198, -2467.7561, -2442.3339, -2433.7232, -2411.1399, -2390.521, -2378.8934, -2355.7085, -2340.7939, -2329.2435, -2324.6802, -2323.1407, -2286.2837, -2272.7462, -2274.5272, -2271.9148, -2269.8324, -2263.9148, -2239.7621, -2221.0158, -2229.9017, -2212.6875, -2200.0159, -2171.0573, -2198.3255, -2197.2246, -2197.4755, -2203.2352, -2194.6816, -2186.2642, -2181.323, -2178.4728, -2189.0199, -2181.7941, -2188.1827, -2175.8274, -2173.6066, -2180.1297, -2186.4258, -2183.8957, -2169.759, -2154.7282, -2172.2921, -2176.4379, -2173.5467, -2159.426, -2161.6048, -2189.6344, -2177.0712, -2181.6409, -2189.9974, -2186.7749, -2181.463, -2189.9807, -2188.4514, -2195.0406, -2191.8196, -2194.305, -2187.2417, -2208.1782, -2200.0116, -2200.3818, -2195.9941, -2167.7074, -2160.822, -2160.7251, -2185.0004, -2179.4202, -2176.9451, -2162.9659, -2164.6985, -2152.8503, -2151.1166, -2132.2592, -2140.9069, -2151
# ...
